# %% [markdown]
# ![alt text](https://www.unsw.edu.au/sites/default/files/UNSW_0.png)
#
# # MARK5828 Lab Quiz 3
#
# ---

# %% [markdown]
# # Question 1: Dataframe Operations (2 marks)

# %% [markdown]
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower.

# %% [markdown]
# Your task is to become familiar with some useful Pandas operations using the iris dataset. (Hint: See Python Lesson 2)
#
# For each question, please try and show the output before you download and submit your .ipynb file.

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

import pandas as pd
import seaborn as sns

iris = sns.load_dataset('iris')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## a) [Code] Indexing & Slicing (0.5 marks)

# %% [markdown]
# **Question**: Extract the **first rows up to when index name equals 10**  of the columns** "sepal_length"** and **"species"** in the **iris** dataset. (Hint: Last row should contain 5.4 | setosa)

# %%
# Write your answer here

iris.loc[:10, ["sepal_length", "species"]]
# Out:
#     sepal_length species
# 0            5.1  setosa
# 1            4.9  setosa
# 2            4.7  setosa
# 3            4.6  setosa
# 4            5.0  setosa
# 5            5.4  setosa
# 6            4.6  setosa
# 7            5.0  setosa
# 8            4.4  setosa
# 9            4.9  setosa
# 10           5.4  setosa

# %% [markdown]
# ## b) [Code] Grouping (0.5 marks)

# %% [markdown]
# **Question**: Calculate the **average** for every numeric column for every unique **species**. (Hint: average petal_width for setosa is 0.246)

# %%
# Write your answer here
iris.groupby(['species']).mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# ## c) [Code] Single Filtering (0.5 marks)

# %% [markdown]
# **Question**: Filter your **iris** dataset so that every **species** are **virginica**. (Hint: petal_width for last row is 1.8)

# %%
# Write your answer here
iris[iris["species"] == "virginica"]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 113           5.7          2.5           5.0          2.0  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 116           6.5          3.0           5.5          1.8  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 119           6.0          2.2           5.0          1.5  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# ## d) [Code] Multiple Filtering (0.5 marks)

# %% [markdown]
# **Question**: Filter your **iris** dataset so that each row has a **sepal_width greater than 3** **AND** a **sepal_length less than or equal to 5**. (Hint: Last row has petal_width of 0.2)

# %%
# Write your answer here

iris_high_att_def = iris[(iris["sepal_width"] > 3) & (iris["sepal_length"] <= 5)] # & is equivalent to the boolean 'and'.
iris_high_att_def.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %% [markdown]
# # Question 2: Samsung vs Apple Comparative Advertising (3 marks)

# %% [markdown]
# In the tutorial, we studied the effects of Comparative Advertising between Samsung and Apple, using the distance (calculated from Multi-dimensional scaling) as the y variable. Your task here is to perform regression analysis using the **similarity** instead of the distance. I have copied most of the code from the tutorial here, and your <font color='Purple'>task is to **find and change** specific lines so that the code will run regression analysis on similarity instead of distance.</font>
#
# (Hint: Make use of the get_similarity function)

# %% [markdown]
# ## a) [Code] Regression Analysis (1 mark)

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

from google.colab import files

# Upload week3_helpers.py, brand_2011-10-27 2012-01-22.csv
files.upload()
# Out:
#      <input type="file" id="files-ca5b73d0-8a06-4905-a674-6ce34482bc35" name="files[]" multiple disabled />
#      <output id="result-ca5b73d0-8a06-4905-a674-6ce34482bc35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving brand_2011-10-27 2012-01-22.csv to brand_2011-10-27 2012-01-22.csv
# {'brand_2011-10-27 2012-01-22.csv': b'Apple Blackberry + iPhone Blackberry,Apple HTC + Apple Evo + iPhone HTC + iPhone Evo,Blackberry HTC + Blackberry Evo,Blackberry Samsung + Blackberry Galaxy,Apple Samsung + Apple Galaxy + iPhone Samsung + iPhone Galaxy,HTC Samsung + HTC Galaxy + Evo Samsung + Evo Galaxy,date\n29.0,28.0,5.0,7.0,49.0,28.000000000000004,2011-10-27\n24.0,28.0,3.0,7.0,57.0,30.999999999999996,2011-10-28\n28.0,24.0,5.0,7.0,61.0,27.000000000000004,2011-10-29\n20.0,28.0,4.0,6.0,54.0,25.0,2011-10-30\n22.0,24.0,3.0,5.0,47.0,38.0,2011-10-31\n22.0,24.0,3.0,6.0,40.0,29.999999999999996,2011-11-01\n21.0,25.0,4.0,7.0,49.0,43.0,2011-11-02\n19.0,26.0,4.0,7.0,40.0,30.999999999999996,2011-11-03\n25.0,21.0,3.0,5.0,47.0,38.0,2011-11-04\n23.0,32.0,5.0,7.0,48.0,36.0,2011-11-05\n24.0,34.0,5.0,6.0,52.0,45.0,2011-11-06\n20.0,24.0,4.0,5.0,38.0,34.0,2011-11-07\n25.0,22.0,5.0,4.0,51.0,35.0,2011-11-08\n25.0,25.0,4.0,5.0,45.0,31.999999999999996,2011-11-09\n20.0,27.0,3.0,4.0,40.0,29.999999999999996,2011-11-10\n24.0,23.0,4.0,5.0,47.0,41.0,2011-11-11\n26.0,28.0,2.0,6.0,48.0,31.999999999999996,2011-11-12\n23.0,27.0,4.0,7.0,46.0,45.0,2011-11-13\n19.0,25.0,3.0,6.0,43.0,36.0,2011-11-14\n20.0,25.0,3.0,4.0,37.0,30.999999999999996,2011-11-15\n25.0,22.0,3.0,5.0,42.0,31.999999999999996,2011-11-16\n20.0,25.0,5.0,9.0,44.0,29.999999999999996,2011-11-17\n21.0,24.0,6.0,5.0,44.0,35.0,2011-11-18\n29.0,19.0,5.0,7.0,45.0,39.0,2011-
.0,19.0,1.0,9.0,49.0,26.0,2012-01-07\n17.0,25.0,4.0,7.0,52.0,28.000000000000004,2012-01-08\n16.0,19.0,1.0,5.0,49.0,28.000000000000004,2012-01-09\n18.0,19.0,3.0,4.0,45.0,23.0,2012-01-10\n19.0,20.0,2.0,6.0,41.0,30.999999999999996,2012-01-11\n19.0,20.0,3.0,6.0,41.0,28.999999999999996,2012-01-12\n23.0,19.0,4.0,4.0,39.0,21.0,2012-01-13\n24.0,21.0,3.0,5.0,61.0,24.0,2012-01-14\n22.0,25.0,3.0,3.0,54.0,24.0,2012-01-15\n23.0,23.0,1.0,5.0,45.0,28.000000000000004,2012-01 ...

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

import math

import numpy as np
import pandas as pd

from sklearn.manifold import MDS

import statsmodels.api as sm

from week3_helpers import chunker, get_keywords_combination
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

"""Variable Definitions"""

BRANDS= ['Apple', 'Blackberry', 'HTC', 'Samsung']
BRANDS_SYNONYMS = ['Apple,iPhone', 'Blackberry', 'HTC,Evo', 'Samsung,Galaxy']
TIMEFRAME = "2011-10-27 2012-01-22"

df = pd.read_csv("brand_" + TIMEFRAME + ".csv") # Google Trends Data
dates = df.pop("date")                          # Remove "date" column from df and store it into variable "dates"

start = list(dates).index("2011-11-24")         # Advertising campaign starts on 24/11/2011
end = start + 5 * 7                             # Advertising campaign goes for 5 weeks (35 days)

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

def create_similarity_matrix(df, i):
  """
  Restructures the dataframe into a similarity matrix.
  """
  brands_keywords = get_keywords_combination(
    brands=BRANDS,
    brands_synonyms=BRANDS_SYNONYMS,
  )

  # brands_keywords dictionary with reversed key, values
  brands_keywords_rev = {v: k for k, v in brands_keywords.items()}
  
  new_df = pd.DataFrame(index=BRANDS, columns=BRANDS)
  for name in df.columns:
    brand_1, brand_2 = brands_keywords_rev[name]
    new_df.loc[brand_1, brand_2] = df.loc[i, name] / 100
    new_df.loc[brand_2, brand_1] = df.loc[i, name] / 100
  return new_df.loc[(new_df!=0).any(axis=1)].fillna(1).astype(np.float64)

def get_x_y(sim_matrix):
  """Converts the similarity matrix into x, y mapped coordinates using Multidimensional Scaling"""
  embedding = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
  res = embedding.fit_transform((1 - np.eye(len(BRANDS))) * (1 - sim_matrix))

  return res[:, 0], res[:, 1]

def get_dist(name_1, name_2):
  """Get list of distances between two brands"""
  result = []
  id1 = BRANDS.index(name_1)
  id2 = BRANDS.index(name_2)
  for date in dates:
    X, Y = get_x_y(sim_matrix_dict[date])
    dist = math.sqrt((X[id1] - X[id2]) ** 2 + (Y[id1] - Y[id2]) ** 2)
    result.append(dist)
  return result

def get_similarity(name_1, name_2):
  """Get list of similarities between two brands"""
  result = []
  for sim_matrix in sim_matrix_dict.values():
    result.append(sim_matrix.loc[name_1][name_2])
  return result

# %%
similarity_matrix_dict = {}
for i, date in enumerate(dates):
  similarity_matrix_dict[date] = create_similarity_matrix(df=df, i=i)

app_similarity = pd.DataFrame(index=dates)
for item in BRANDS:
  app_similarity[item] = get_similarity("Apple", item)

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

after_var = pd.Series()
for i, item in enumerate(chunker(dates[end+1:], 7)):
  item_copy = item.copy()
  item_copy[:] = "week_" + str(i+1)
  after_var = after_var.append(item_copy)
after_var.index = dates[end+1:]

# %%
ad_period_df = pd.DataFrame()                    # Initialise Empty Dataframe (Table)

"""For each iteration in this loop, we are defining a new dataframe (brand_df) for each brand. After defining the new dataframe, we append it to the main dataframe (ad_period_df)"""
for brand in ["Samsung", "HTC", "Blackberry"]:   # Loop through each Brand
  brand_df = pd.DataFrame({
    "app_similarity": list(app_similarity[brand]),           # Similarity from brand to Apple stored in column "app_similarity"
    "brand_pair": [brand] * len(dates),          # Brand {Samsung, HTC, Blackberry} stored in "brand_pair" 
    "day": dates,                                # All 88 dates stored in "day"
    "during": [0] * len(dates),                  # During defined as 1 ONLY if brand is Samsung and date is during the marketing campaign (0 otherwise)
    "after": [0] * len(dates)                    # After defined as either week_1, week_2, week_3 or week_4 ONLY if brand is Samsung and date is after the marketing campaign (0 otherwise)
  })
  
  if brand == "Samsung":                         # Conditional Statement to help define the during and after variables
    brand_df.loc[start:end, "during"] = 1
    brand_df.loc[end+1:len(dates), "after"] = list(after_var)
  ad_period_df = pd.concat([ad_period_df, brand_df], axis=0, ignore_index=True)   # Join "brand_df" at the end of "ad_period_df"

# %%
ad_period_dummies_df = pd.get_dummies(ad_period_df, columns=['after', 'brand_pair', 'day'], drop_first=True)

# %%
y = ad_period_dummies_df.pop("app_similarity")

# %%
X = sm.add_constant(ad_period_dummies_df)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         app_similarity   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     30.22
# Date:                Tue, 12 Mar 2019   Prob (F-statistic):           6.63e-72
# Time:                        11:25:34   Log-Likelihood:                 498.26
# No. Observations:                 264   AIC:                            -806.5
# Df Residuals:                     169   BIC:                            -466.8
# Df Model:                          94
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.2617      0.027      9.725      0.000       0.209       0.315
# during                 0.1171      0.014      8.286      0.000       0.089       0.145
# after_week_1           0.0468      0.024      1.973      0.050   -1.72e-05       0.094
# after_week_2           0.0325      0.024      1.371      0.172      -0.014       0.079
# after_week_3           0.0268      0.024      1.130      0.260      -0.020       0.074
# after_week_4           0.0030      0.034      0.087      0.931      -0.064       0.070
# brand_pair_HTC         0.0298      0.007      4.311      0.000       0.016       0.043
# brand_pair_Samsung     0.2452      0.011     21.993      0.000       0.223       0.267
# day_2011-10-28         0.0100      0.037      0.267      0.790      -0.064       0.084
# day_2011-10-29         0.0233      0.037      0.624      0.534      -0.051       0.097
# day_2011-10-30        -0.0133      0.037     -0.356      0.722      -0.087       0.061
# day_2011-10-31        -0.0433      0.037     -1.159      0.248      -0.117       0.031
# day_2011-11-01        -0.0667      0.037     -1.782      0.076      -0.141       0.007
# day_2011-11-02        -0.0367      0.037     -0.980      0.328      -0.111       0.037
# day_2011-11-03        -0.0700      0.037     -1.872      0.063      -0.144       0.004
# day_2011-11-04        -0.0433      0.037     -1.159      0.248      -0.117       0.031
# day_2011-11-05        -0.0100      0.037     -0.267      0.790      -0.084       0.064

# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
"""YOU DO NOT NEED TO MODIFY THIS"""

# Classifying Columns to non-control, control (sort of hard-coded)
non_control_cols = [column for column in X.columns if column == "during" or "after_week_" in column]
control_cols = [column for column in X.columns if not(column == "during" or "after_week_" in column)]

# Coefficients and p-values
df_coeffs = pd.DataFrame({"Coefficients": model.params, "p": model.pvalues})

# Create two sorted dataframes (1 for non-control; 1 for control)
df_coeffs_sig = df_coeffs.loc[non_control_cols, :]
df_coeffs_control = df_coeffs.loc[control_cols, :]
df_coeffs_sig_sorted = df_coeffs_sig.reindex(df_coeffs_sig["p"].sort_values().index)
df_coeffs_control_sorted = df_coeffs_control.reindex(df_coeffs_control["p"].sort_values().index)

# Print Result
pd.concat([df_coeffs_sig_sorted, df_coeffs_control_sorted], axis=0).style.bar(subset = ["Coefficients", "p"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 62.0%, transparent 62.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.0%, transparent 0.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 43.5%, transparent 43.5%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 5.0%, transparent 5.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 39.8%, transparent 39.8%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 17.2%, transparent 17.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 38.3%, transparent 38.3%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 26.0%, transparent 26.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 32.0%, transparent 32.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 93.1%, transparent 93.1%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 95.7%, transparent 95.7%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.0%, transparent 0.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.0%, transparent 0.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 83.2%, transparent 83.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.0%, transparent 0.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 75.3%, transparent 75.3%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.0%, transparent 0.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 39.1%, transparent 39.1%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.0%, transparent 0.0%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 63.9%, transparent 63.9%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.1%, transparent 0.1%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 63.9%, transparent 63.9%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.1%, transparent 0.1%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 31.2%, transparent 31.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.2%, transparent 0.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 3.5%, #d65f5f 3.5%, #d65f5f 31.2%, transparent 31.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 0.6%, transparent 0.6%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 5.6%, #d65f5f 5.6%, #d65f5f 31.2%, transparent 31.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 1.2%, transparent 1.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 5.6%, #d65f5f 5.6%, #d65f5f 31.2%, transparent 31.2%);
#         }    #T_9103a4e2_44b9_11e9_862d_0242ac1c0002row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 1.2%, transparent 1.2%);
#         }    #T_9103a4e2_44b9_11e9_

# %% [markdown]
# ## c) [Written] Significance of your results (2 marks)

# %% [markdown]
# **Question**: Have a look at the **during** results from your regression analysis from your code (**similarity**) and the tutorial code (**distance**).
#
# What are the differences? (1 mark).
#
# Does both regression analysis lead to the same conclusion? Explain briefly. (1 mark)

# %% [markdown]
# **Answer**:
# {1}. the p-value of "during" results from similarity regression analysis is less than 0.05,and its coefficient is 0.117143.In the distance regression analysis  the P-value is less than 0.05 but its coefficient is -0.0705196,so it shows opposite results.
# {2}.Accoring to the coefficient of two analysis, the distance shows a negative relationship and similarity shows a positive relationship,I think it can lead to same conclusion because the similarity of Apple and Samsung is more significant during the compaign.
